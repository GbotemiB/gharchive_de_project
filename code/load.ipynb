# %%
import findspark
findspark.init()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import findspark
#       2 findspark.init()
#
# ModuleNotFoundError: No module named 'findspark'

# %%
import pyspark
from pyspark.sql import SparkSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pyspark
#       2 from pyspark.sql import SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import pyspark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pyspark
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
# !ls pq/2015/01/01
# Out:
# 2015-01-01-1.parquet   2015-01-01-17.parquet  2015-01-01-4.parquet
# 2015-01-01-10.parquet  2015-01-01-18.parquet  2015-01-01-5.parquet
# 2015-01-01-11.parquet  2015-01-01-19.parquet  2015-01-01-6.parquet
# 2015-01-01-12.parquet  2015-01-01-2.parquet   2015-01-01-7.parquet
# 2015-01-01-13.parquet  2015-01-01-20.parquet  2015-01-01-8.parquet
# 2015-01-01-14.parquet  2015-01-01-21.parquet  2015-01-01-9.parquet
# 2015-01-01-15.parquet  2015-01-01-22.parquet
# 2015-01-01-16.parquet  2015-01-01-3.parquet

# %%
df = pd.read_parquet('pq/2015/01/01/2015-01-01-1.parquet')

# %%
df.head()
# Out:
#            id              type  \
# 0  2489395767         PushEvent
# 1  2489395768         PushEvent
# 2  2489395770  PullRequestEvent
# 3  2489395771         PushEvent
# 4  2489395775        WatchEvent
#
#                                                actor  \
# 0  {'avatar_url': 'https://avatars.githubusercont...
# 1  {'avatar_url': 'https://avatars.githubusercont...
# 2  {'avatar_url': 'https://avatars.githubusercont...
# 3  {'avatar_url': 'https://avatars.githubusercont...
# 4  {'avatar_url': 'https://avatars.githubusercont...
#
#                                                 repo  \
# 0  {'id': 28067809, 'name': 'soumith/fbcunn', 'ur...
# 1  {'id': 20022094, 'name': 'radix/effect', 'url'...
# 2  {'id': 17165658, 'name': 'apache/spark', 'url'...
# 3  {'id': 17165658, 'name': 'apache/spark', 'url'...
# 4  {'id': 3073296, 'name': 'SirVer/ultisnips', 'u...
#
#                                              payload  public  \
# ...

# %%
df.shape
# Out:
# (7427, 8)

# %%
df['actor'][2]
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/1341245?',
#  'gravatar_id': '',
#  'id': 1341245,
#  'login': 'asfgit',
#  'url': 'https://api.github.com/users/asfgit'}

# %%
df['repo'][2]
# Out:
# {'id': 17165658,
#  'name': 'apache/spark',
#  'url': 'https://api.github.com/repos/apache/spark'}

# %%
df['org'][2]
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/47359?',
#  'gravatar_id': '',
#  'id': 47359.0,
#  'login': 'apache',
#  'url': 'https://api.github.com/orgs/apache'}

# %%
df['payload'][2]
# Out:
# {'action': 'closed',
#  'before': None,
#  'comment': None,
#  'commits': None,
#  'description': None,
#  'distinct_size': None,
#  'forkee': None,
#  'head': None,
#  'issue': None,
#  'master_branch': None,
#  'member': None,
#  'number': 3842.0,
#  'pages': None,
#  'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/apache/spark/issues/3842/comments'},
#    'commits': {'href': 'https://api.github.com/repos/apache/spark/pulls/3842/commits'},
#    'html': {'href': 'https://github.com/apache/spark/pull/3842'},
#    'issue': {'href': 'https://api.github.com/repos/apache/spark/issues/3842'},
#    'review_comment': {'href': 'https://api.github.com/repos/apache/spark/pulls/comments/{number}'},
#    'review_comments': {'href': 'https://api.github.com/repos/apache/spark/pulls/3842/comments'},
#    'self': {'href': 'https://api.github.com/repos/apache/spark/pulls/3842'},
# ...
